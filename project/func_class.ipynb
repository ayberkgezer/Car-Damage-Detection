# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.random.rand(10)

# %%
X
# Out:
# array([0.35521281, 0.61206138, 0.27615098, 0.18227123, 0.71031632,
#        0.61006454, 0.60043441, 0.60448032, 0.15468318, 0.05657977])

# %%
def simple(x):
    return (4*x + 5)

# %%
simple
# Out:
# <function __main__.simple(x)>

# %%
Y = simple(X)

# %%
Y
# Out:
# array([6.42085125, 7.44824552, 6.10460392, 5.72908491, 7.84126526,
#        7.44025817, 7.40173766, 7.41792126, 5.61873271, 5.22631908])

# %%
plt.plot(X,Y)
